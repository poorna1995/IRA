# %%
import pandas as pd
df = pd.read_parquet("../datasets/processed/mmlu_pro.parquet")
print(df.shape)
print(df.columns.tolist())
print(df.head(3))
# Out:
#           id                                              query answer  \
# 11065  11287     The errors mainly caused by human mistakes are      A
# 766      843  Mary Anne, a piece-worker, makes 370 units eac...      G
# 5944    6105  A 67-year-old man with Parkinson disease is ad...      J
# 9435    9624  A copper kettle, the circular bottom of which ...      I
# 9815   10009  The mean solar flux at Earth's surface is $\si...      F
#
#        answer_index                                            options  \
# 11065             0  [gross error., instrumental error., systematic...
# 766               6  [470 units, 485 units, 430 units, 391 units, 4...
# 5944              9  [Place a percutaneous endoscopic gastrostomy (...
# 9435              8  [15 Btu, 25 Btu, 28 Btu, 20 Btu, 30 Btu, 18 Bt...
# 9815              5  [16.8 $\mathrm{~m}^2$, 23.5 $\mathrm{~m}^2$, 1...
#
#           category cot_content                              src  cot_length
# ...
