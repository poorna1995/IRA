# %%
import pandas as pd
df = pd.read_parquet("../datasets/processed/gaia.parquet")
print(df.shape)
print(df.columns.tolist())
# Out:
# (165, 7)
# ['id', 'query', 'answer', 'level', 'annotator_steps', 'annotator_tools', 'file_name']

# %%
question = df["query"]

# %%
question
# Out:
# 0      A paper about AI regulation that was originall...
# 1      I’m researching species that became invasive a...
# 2      If we assume all articles published by Nature ...
# 3      In Unlambda, what exact charcter or text needs...
# 4      If Eliud Kipchoge could maintain his record-ma...
#                              ...
# 160    In NASA's Astronomy Picture of the Day on 2006...
# 161    In the film Goldfinger, what color was the obj...
# 162    As of May 2023, how many stops are between Sou...
# 163    In the 2015 Metropolitan Museum of Art exhibit...
# 164    At the two-minute mark in the YouTube video up...
# Name: query, Length: 165, dtype: str
